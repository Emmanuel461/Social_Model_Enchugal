# %% [markdown]
# ## Prepare the data of Dependent variables.

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: numpy in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: scipy in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: matplotlib in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 5)) (3.9.1)
# Requirement already satisfied: seaborn in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: openpyxl in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 7)) (3.1.5)
# Requirement already satisfied: statsmodels in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 8)) (0.14.2)
# Requirement already satisfied: geopy in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 9)) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\merlinleunda\appdata\roaming\python\python311\site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->-r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\merlinleunda\appdata\roaming\python\python311\site-packages (from matplotlib->-r requirements.txt (line 5)) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from openpyxl->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from statsmodels->-r requirements.txt (line 8)) (0.5.6)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\merlinleunda\appdata\local\programs\python\python311\lib\site-packages (from geopy->-r requirements.txt (line 9)) (2.0)
# Requirement already satisfied: six in c:\users\merlinleunda\appdata\roaming\python\python311\site-packages (from patsy>=0.5.6->statsmodels->-r requirements.txt (line 8)) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import os
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# 1. **Here is an important point. If you want to model with Indeg, leave the execution of the next cell without changing anything. If you want to model with 'OutDeg' you should delete 'Indeg' and write 'OutDeg'.**

# %%
import pandas as pd
import os
import re

# Dictionary of Excel files with their respective sheets
file_sheet_dict = {
    "../DataIn/VarDep/23_Var.Dep_Rede_EntreajudaLabur.xlsx": "HelpLabur_CentalitybByNodes",
    "../DataIn/VarDep/24_Var.Dep_RedeControlExtAusencia.xlsx": "ContrlExtAusenc_Trasp_Centr",
    "../DataIn/VarDep/25_Var.Dep_ApoioSpecDiqCint.xlsx": "ApoiSpecDiqCint_Transp_Centr",
    "../DataIn/VarDep/26_Var.Dep_ApoioSpecTubos.xlsx": "ApoioSpecTubos_Transp_Centr",
    "../DataIn/VarDep/29_Var.Dep_RedApoiLevntDiCin.xlsx": "ApoioLevantDiqCin_Transp_Centr",
    "../DataIn/VarDep/32_Var.Dep_RedCont_DiqPriqDiqCint.xlsx": "ControlDiqPriqCint_trans_Centr",
    "../DataIn/VarDep/35_Var.Dep_RedeRepar_DiqPriqDiqCint.xlsx": "ReparDiqPriqCint_trans_Centr",
    "../DataIn/VarDep/36_Var.Dep_Red-Val_Cont1Rep2DiqCin.xlsx": "DiqCintCont1Rep2_trans_Centr",
    "../DataIn/VarDep/37_Var.Dep_Red-Val_Cont1Rep2DiqPrq.xlsx": "DiqPriqContr1Rep2_trans_Centr",
    "../DataIn/VarDep/38_Var.Dep_Red-Val_ContRep2_DiqPrqCin.xlsx": "ContRepDiqPriqCint_trans_Centr",
    "../DataIn/VarDep/39_Var.Dep_RedePartilhaAgu.xlsx": "RedePartilhaAgua_CentrbByNodes",
}

# Function to generate a short suffix based on the filename
def generate_short_suffix(file_name):
    base_name = os.path.splitext(os.path.basename(file_name))[0]
    parts = base_name.split('_')
    # Use the last two parts of the name as a suffix.
    return '_'.join(parts[-2:])

# Read each file and store the data in a dictionary
data_frames = {}

for file, sheet_name in file_sheet_dict.items():
    try:
        # Read the specified sheet
        df = pd.read_excel(file, sheet_name=sheet_name)
        
        # Select only columns containing 'Indeg', 'Deg', or 'id'.
        cols_to_keep = [col for col in df.columns if re.fullmatch(r'Indeg|Degree|id', col)]
        df = df[cols_to_keep]
        
        # Generate a short suffix based on the file name
        suffix = generate_short_suffix(file)
        
        # Add suffix to the columns
        df = df.add_suffix(f'_{suffix}')
        
        # Rename the id column to have a consistent name
        df = df.rename(columns={f'id_{suffix}': 'id'})
        
        data_frames[suffix] = df
        print(f"File {file} read successfully with suffix {suffix}.")
    except Exception as e:
        print(f"Error reading file {file}: {e}")

# Initialize the resulting DataFrame with the first DataFrame in the dictionary
result_df = None

for suffix, df in data_frames.items():
    if result_df is None:
        result_df = df
    else:
        result_df = pd.merge(result_df, df, on='id', how='outer')

# Save the resulting DataFrame to a CSV file
output_path = "../DataIntermediate/combined_data_dep_variables.csv"
os.makedirs("../DataIntermediate/", exist_ok=True)
try:
    # Remove the row with the producer name 'Sumfone Tagadad'
    result_df = result_df[result_df['id'] != 'Sumfone Tagadad']
    result_df.to_csv(output_path, index=False)
    print(f"Combined file saved successfully at {output_path}.")
    print(f"Dimensions of the resulting DataFrame: {result_df.shape}")
except Exception as e:
    print(f"Error saving the combined file: {e}")
# Out:
# Archivo ../DataIn/VarDep/23_Var.Dep_Rede_EntreajudaLabur.xlsx leído exitosamente con sufijo Rede_EntreajudaLabur.
# Archivo ../DataIn/VarDep/24_Var.Dep_RedeControlExtAusencia.xlsx leído exitosamente con sufijo Var.Dep_RedeControlExtAusencia.
# Archivo ../DataIn/VarDep/25_Var.Dep_ApoioSpecDiqCint.xlsx leído exitosamente con sufijo Var.Dep_ApoioSpecDiqCint.
# Archivo ../DataIn/VarDep/26_Var.Dep_ApoioSpecTubos.xlsx leído exitosamente con sufijo Var.Dep_ApoioSpecTubos.
# Archivo ../DataIn/VarDep/29_Var.Dep_RedApoiLevntDiCin.xlsx leído exitosamente con sufijo Var.Dep_RedApoiLevntDiCin.
# Archivo ../DataIn/VarDep/32_Var.Dep_RedCont_DiqPriqDiqCint.xlsx leído exitosamente con sufijo RedCont_DiqPriqDiqCint.
# Archivo ../DataIn/VarDep/35_Var.Dep_RedeRepar_DiqPriqDiqCint.xlsx leído exitosamente con sufijo RedeRepar_DiqPriqDiqCint.
# Archivo ../DataIn/VarDep/36_Var.Dep_Red-Val_Cont1Rep2DiqCin.xlsx leído exitosamente con sufijo Red-Val_Cont1Rep2DiqCin.
# Archivo ../DataIn/VarDep/37_Var.Dep_Red-Val_Cont1Rep2DiqPrq.xlsx leído exitosamente con sufijo Red-Val_Cont1Rep2DiqPrq.
# Archivo ../DataIn/VarDep/38_Var.Dep_Red-Val_ContRep2_DiqPrqCin.xlsx leído exitosamente con sufijo ContRep2_DiqPrqCin.
# Archivo ../DataIn/VarDep/39_Var.Dep_RedePartilhaAgu.xlsx leído exitosamente con sufijo Var.Dep_RedePartilhaAgu.
# Archivo combinado guardado exitosamente en ../DataIntermediate/combined_data_dep_variables.csv.
# Dimensiones del DataFrame resultante: (129, 12)

# %%
data_frame_combinado = pd.read_csv('../DataIntermediate/combined_data_dep_variables.csv', sep = ',')

data_frame_combinado
# Out:
#                     id  Degree_Rede_EntreajudaLabur  \
# 0          Aiace Quior                            7
# 1          Alamada Bia                            2
# 2     Alanghate Mfumba                           10
# 3        Albat Calabus                           10
# 4     Americano Mbunde                           19
# ..                 ...                          ...
# 124     Vieira Bedugle                            9
# 125  Viriato Quintunda                           12
# 126     Wangna Ntchoba                           15
# 127     Wilndan Tchuda                            9
# 128     Winaba Ndongle                            9
#
#      Indeg_Var.Dep_RedeControlExtAusencia  Indeg_Var.Dep_ApoioSpecDiqCint  \
# 0                                       1                               4
# 1                                       2                               4
# 2                                       1                               0
# 3                                       0                               2
# 4                                       1                               1
# ..                                    ...                             ...
# 124                                     4                               2
# 125                                     1                               1
# 126                                     0                               1
# 127                                     1                               2
# 128                                     0                               1
#
#      Indeg_Var.Dep_ApoioSpecTubos  Indeg_Var.Dep_RedApoiLevntDiCin  \
# 0                               2                                1
# 1                               2                                0
# 2                               0                                0
# 3                               0                                0
# 4                               2                                0
# ..                            ...                              ...
# 124                             1                                0
# 125                             1                                1
# 126                             1                                1
# 127                             1                                2
# 128                             1                                1
#
#      Indeg_RedCont_DiqPriqDiqCint  Indeg_RedeRepar_DiqPriqDiqCint  \
# 0                               1                               0
# 1                               2                               2
# 2                               2                               1
# 3                               2                               2
# 4                               2                               2
# ..                            ...                             ...
# 124                             1                               0
# 125                             3                               2
# 126                             2                               1
# 127                             1                               0
# 128                             3                               1
#
#      Indeg_Red-Val_Cont1Rep2DiqCin  Indeg_Red-Val_Cont1Rep2DiqPrq  \
# 0                                1                              1
# 1                                0                              4
# 2                                0                              3
# 3                                0                              4
# 4                                0                              4
# ..                             ...                            ...
# 124                              1                              1
# 125                              3                              5
# 126                              2                              3
# 127                              1                              1
# 128                              2                              4
#
#      Indeg_ContRep2_DiqPrqCin  Indeg_Var.Dep_RedePartilhaAgu
# 0                           1                              0
# 1                           4                              0
# 2                           3                              0
# 3                           4                              0
# 4                           4                              0
# ..                        ...                            ...
# 124                         1                              2
# 125                         5                              2
# 126                         3                              3
# 127                         1                              1
# 128                         4                              3
#
# [129 rows x 12 columns]

# %% [markdown]
# ## Prepare the data of Indepedent variables (variables for model).

# %%
import pandas as pd
import os
import re

# Dictionary of Excel files with their respective sheets
file_sheet_dict_indep = {
    "../DataIn/VarExpl/0018_Rev_Var.Expl_RedConfliAguaTot.xlsx": "RedConfltAguTot_CentlitybByNod",
    "../DataIn/VarExpl/0019.1_RevV.Expl_RedConfliAguaReso.xlsx": "RedConfliAguaRes_CentlitybByNod",
    "../DataIn/VarExpl/12_Var.Explic_FamiRedIrmonsPrimos.xlsx": "RedeIrmonsPrimo_CentlitybByNods",
    "../DataIn/VarExpl/13_Var.Explic_FamiRedPaiTiopatCriadr.xlsx": "PaiTiopaterCriador_Transp_Centr",
    "../DataIn/VarExpl/14_Var.Explic_FamiRedTiosMaternos.xlsx": "TiosMaternos_Transp_Centr",
    "../DataIn/VarExpl/15.1_V.Expl_Red_IntimAmigUndir.xlsx": "IntimAmigUndi_CentalitybByNodes",
    "../DataIn/VarExpl/15_Var.Explic_Rede_IntimAmigos.xlsx": "IntimAmigos_CentalitybByNodes",
    "../DataIn/VarExpl/16_Var.Explic_RedeRisk.xlsx": "RedeRisk_CentalitybByNodes",
    "../DataIn/VarExpl/17_Var.Explic_Rede_Confianca.xlsx": "RedeConfianca_CentalityByNodes",
    "../DataIn/VarExpl/19_Var.Explic_RedeConflitAguaPersist.xlsx": "RedeConflitAgua_CentlitybByNod",
    "../DataIn/VarExpl/20_RevVar.Expl_RedConflitGeralTot.xlsx": "RedeConflitGerTo_CentlitybByNod",
    "../DataIn/VarExpl/21_Var.Explic_RedeConflitGeralPersist.xlsx": "RedeConflitGerPe_CentlitybByNod",
    "../DataIn/VarExpl/Duda_22.1_Var.Explic_RedeVendaParcel.xlsx": "VendaParcela_Transp_Centr",
    "../DataIn/VarExpl/Duda_22_Var.Explic_RedeEmprestParcel.xlsx": "EmprestParcela_Centr",
    "../DataIn/VarDep/Data_Superf_NumZonas.xlsx": "Data_area",
    "../DataIntermediate/PCA_Dist_Prod.xlsx" : "Distance_Prods",
    "../DataIntermediate/Distancias_promedio_casas_parcelas.xlsx" : "Dist_moranza_parcel",
    "../DataIn/VarExpl/12-13-14_Var.Explic_FamiTotal.xlsx": "RedeTotFamily_CentlitybByNods"
}

# %% [markdown]
# 1. **Here is an important point. If you want to model with Indeg, leave the execution of the next cell without changing anything. If you want to model with 'OutDeg' you should delete 'Indeg' and type 'OutDeg'** NOTE: this will modify all the outputs, so it is recommended that once you run you copy the data from the 'Result' folder and store it in another folder.

# %%
# Read each file and store the data in a dictionary
data_frames_indep = {}

for file, sheet_name in file_sheet_dict_indep.items():
    try:
        # Read the Excel file
        df = pd.read_excel(file, sheet_name=sheet_name)
        
        # Select only the columns that exactly contain 'OutDeg', 'Degree', 'PC1', 'PC2', 'Avg_Distancia', or 'id'
        cols_to_keep = [col for col in df.columns if re.fullmatch(r'OutDeg|Degree|PC1|PC2|Avg_Distancia|id', col)]
        df = df[cols_to_keep]
        
        # Generate a short suffix based on the sheet name
        suffix = sheet_name[:12]  # Use the first 12 characters of the sheet name as the suffix
        
        # Add suffix to the columns
        df = df.add_suffix(f'_{suffix}')
        
        # Rename the id column to have a consistent name
        df = df.rename(columns={f'id_{suffix}': 'id'})
        
        data_frames_indep[suffix] = df
        print(f"File {file} read successfully with suffix {suffix}.")
    except Exception as e:
        print(f"Error reading file {file}: {e}")

# Process the file "Atributos_Productores.xlsx"
atributos_productores_path = "../DataIn/VarExpl/Atributos_Productores.xlsx"
try:
    atributos_productores_df = pd.read_excel(atributos_productores_path, sheet_name="Sheet1")
    print(f"File {atributos_productores_path} read successfully.")
except Exception as e:
    print(f"Error reading the file {atributos_productores_path}: {e}")

# Initialize the resulting DataFrame with the first DataFrame in the dictionary
result_df = None

for suffix, df in data_frames_indep.items():
    if result_df is None:
        result_df = df
    else:
        result_df = pd.merge(result_df, df, on='id', how='outer')

# Combine the resulting DataFrame with the "Atributos_Productores" DataFrame
final_result_df = pd.merge(result_df, atributos_productores_df, on='id', how='outer')

# Remove the row with the producer name 'Sumfone Tagadad'
final_result_df = final_result_df[final_result_df['id'] != 'Sumfone Tagadad']

# Save the resulting DataFrame to a CSV file
output_path = "../DataIntermediate/combined_data_indep_variables.csv"
os.makedirs("../DataIntermediate/", exist_ok=True)
try:
    final_result_df.to_csv(output_path, index=False)
    print(f"Combined file saved successfully at {output_path}.")
    print(f"Dimensions of the resulting DataFrame: {final_result_df.shape}")
except Exception as e:
    print(f"Error saving the combined file: {e}")
# Out:
# Archivo ../DataIn/VarExpl/0018_Rev_Var.Expl_RedConfliAguaTot.xlsx leído exitosamente con sufijo RedConfltAgu.
# Archivo ../DataIn/VarExpl/0019.1_RevV.Expl_RedConfliAguaReso.xlsx leído exitosamente con sufijo RedConfliAgu.
# Archivo ../DataIn/VarExpl/12_Var.Explic_FamiRedIrmonsPrimos.xlsx leído exitosamente con sufijo RedeIrmonsPr.
# Archivo ../DataIn/VarExpl/13_Var.Explic_FamiRedPaiTiopatCriadr.xlsx leído exitosamente con sufijo PaiTiopaterC.
# Archivo ../DataIn/VarExpl/14_Var.Explic_FamiRedTiosMaternos.xlsx leído exitosamente con sufijo TiosMaternos.
# Archivo ../DataIn/VarExpl/15.1_V.Expl_Red_IntimAmigUndir.xlsx leído exitosamente con sufijo IntimAmigUnd.
# Archivo ../DataIn/VarExpl/15_Var.Explic_Rede_IntimAmigos.xlsx leído exitosamente con sufijo IntimAmigos_.
# Archivo ../DataIn/VarExpl/16_Var.Explic_RedeRisk.xlsx leído exitosamente con sufijo RedeRisk_Cen.
# Archivo ../DataIn/VarExpl/17_Var.Explic_Rede_Confianca.xlsx leído exitosamente con sufijo RedeConfianc.
# Archivo ../DataIn/VarExpl/19_Var.Explic_RedeConflitAguaPersist.xlsx leído exitosamente con sufijo RedeConflitA.
# Archivo ../DataIn/VarExpl/20_RevVar.Expl_RedConflitGeralTot.xlsx leído exitosamente con sufijo RedeConflitG.
# Archivo ../DataIn/VarExpl/21_Var.Explic_RedeConflitGeralPersist.xlsx leído exitosamente con sufijo RedeConflitG.
# Archivo ../DataIn/VarExpl/Duda_22.1_Var.Explic_RedeVendaParcel.xlsx leído exitosamente con sufijo VendaParcela.
# Archivo ../DataIn/VarExpl/Duda_22_Var.Explic_RedeEmprestParcel.xlsx leído exitosamente con sufijo EmprestParce.
# Archivo ../DataIn/VarDep/Data_Superf_NumZonas.xlsx leído exitosamente con sufijo Data_area.
# Archivo ../DataIntermediate/PCA_Dist_Prod.xlsx leído exitosamente con sufijo Distance_Pro.
# Archivo ../DataIntermediate/Distancias_promedio_casas_parcelas.xlsx leído exitosamente con sufijo Dist_moranza.
# Archivo ../DataIn/VarExpl/12-13-14_Var.Explic_FamiTotal.xlsx leído exitosamente con sufijo RedeTotFamil.
# Archivo ../DataIn/VarExpl/Atributos_Productores.xlsx leído exitosamente.
# Archivo combinado guardado exitosamente en ../DataIntermediate/combined_data_indep_variables.csv.
# Dimensiones del DataFrame resultante: (129, 29)

# %%
data_frame_combinado_indep = pd.read_csv('../DataIntermediate/combined_data_indep_variables.csv', sep = ',')

data_frame_combinado_indep
# Out:
#                     id  OutDeg_RedConfltAgu  Degree_RedConfliAgu  \
# 0          Aiace Quior                    0                    0
# 1          Alamada Bia                    0                    0
# 2     Alanghate Mfumba                    0                    0
# 3        Albat Calabus                    0                    0
# 4     Americano Mbunde                    0                    0
# ..                 ...                  ...                  ...
# 124     Vieira Bedugle                    3                    3
# 125  Viriato Quintunda                    0                    0
# 126     Wangna Ntchoba                    0                    0
# 127     Wilndan Tchuda                    0                    0
# 128     Winaba Ndongle                    0                    0
#
#      Degree_RedeIrmonsPr  OutDeg_PaiTiopaterC  OutDeg_TiosMaternos  \
# 0                      3                    0                    0
# 1                      0                    0                    0
# 2                      0                    0                    0
# 3                      0                    0                    2
# 4                      2                    0                    3
# ..                   ...                  ...                  ...
# 124                    0                    0                    0
# 125                    4                    0                    0
# 126                    0                    0                    1
# 127                    0                    0                    0
# 128                    1                    0                    0
#
#      Degree_IntimAmigUnd  OutDeg_IntimAmigos_  OutDeg_RedeRisk_Cen  \
# 0                      8                    2                    3
# 1                      4                    4                    0
# 2                      3                    2                    0
# 3                      6                    4                    1
# 4                      1                    1                    0
# ..                   ...                  ...                  ...
# 124                    9                    4                    8
# 125                   12                    5                    2
# 126                    3                    2                    2
# 127                    4                    4                    0
# 128                    9                    1                    2
#
#      OutDeg_RedeConfianc  ...  2_VarExp_Atri_Tabanca  3_VarExp_Atri_Fanado  \
# 0                      2  ...               Ntchugal                     0
# 1                      1  ...                  Fanhi                     0
# 2                      3  ...                 Bsoran                     0
# 3                      2  ...                 Bsoran                     1
# 4                      2  ...                  Fanhi                     0
# ..                   ...  ...                    ...                   ...
# 124                    1  ...               Ntchugal                     1
# 125                    2  ...               Ntchugal                     1
# 126                    1  ...               Ntchugal                     1
# 127                    1  ...               Ntchugal                     1
# 128                    2  ...               Ntchugal                     1
#
#      4_VarExp_Atri_CargosWM  5_VarExp_Atri_Idade  6_VarExp_Atri_ClassIdade  \
# 0                         0                   53                         2
# 1                         0                   37                         2
# 2                         0                   25                         1
# 3                         0                   48                         2
# 4                         0                   30                         1
# ..                      ...                  ...                       ...
# 124                       0                   52                         2
# 125                       0                   51                         2
# 126                       0                   78                         3
# 127                       0                   52                         2
# 128                       0                   60                         2
#
#      7_VarExp_Atri_IndForcaFugon  8_VarExp_Atri_IndInvestDiq  \
# 0                            1.0                           3
# 1                            1.0                           1
# 2                            1.0                           4
# 3                            2.0                           4
# 4                            1.0                           2
# ..                           ...                         ...
# 124                          2.0                           4
# 125                          3.0                           2
# 126                          2.0                           1
# 127                          1.0                           4
# 128                          4.0                           3
#
#      9_VarExp_Atri_IndMelhorTecnDiqCint 10_VarExp_Atri_MelhorTecnTubos  \
# 0                                     3                              0
# 1                                     0                              0
# 2                                     3                              1
# 3                                     3                              0
# 4                                     1                              0
# ..                                  ...                            ...
# 124                                  16                              1
# 125                                   7                              0
# 126                                   1                              0
# 127                                   3                              0
# 128                                   7                              1
#
#     Area_bolanha
# 0         2.3644
# 1         0.5087
# 2         1.4640
# 3         1.5186
# 4         0.2500
# ..           ...
# 124       4.7238
# 125       5.3823
# 126       2.9833
# 127       1.3262
# 128       2.0350
#
# [129 rows x 29 columns]

# %% [markdown]
# ## Export all the data of the dependent variables (indeg as outdeg)

# %%
import pandas as pd
import os
import re

# Dictionary of Excel files with their respective sheets
file_sheet_dict = {
    "../DataIn/VarDep/23_Var.Dep_Rede_EntreajudaLabur.xlsx": "HelpLabur_CentalitybByNodes",
    "../DataIn/VarDep/24_Var.Dep_RedeControlExtAusencia.xlsx": "ContrlExtAusenc_Trasp_Centr",
    "../DataIn/VarDep/25_Var.Dep_ApoioSpecDiqCint.xlsx": "ApoiSpecDiqCint_Transp_Centr",
    "../DataIn/VarDep/26_Var.Dep_ApoioSpecTubos.xlsx": "ApoioSpecTubos_Transp_Centr",
    "../DataIn/VarDep/29_Var.Dep_RedApoiLevntDiCin.xlsx": "ApoioLevantDiqCin_Transp_Centr",
    "../DataIn/VarDep/32_Var.Dep_RedCont_DiqPriqDiqCint.xlsx": "ControlDiqPriqCint_trans_Centr",
    "../DataIn/VarDep/35_Var.Dep_RedeRepar_DiqPriqDiqCint.xlsx": "ReparDiqPriqCint_trans_Centr",
    "../DataIn/VarDep/36_Var.Dep_Red-Val_Cont1Rep2DiqCin.xlsx": "DiqCintCont1Rep2_trans_Centr",
    "../DataIn/VarDep/37_Var.Dep_Red-Val_Cont1Rep2DiqPrq.xlsx": "DiqPriqContr1Rep2_trans_Centr",
    "../DataIn/VarDep/38_Var.Dep_Red-Val_ContRep2_DiqPrqCin.xlsx": "ContRepDiqPriqCint_trans_Centr",
    "../DataIn/VarDep/39_Var.Dep_RedePartilhaAgu.xlsx": "RedePartilhaAgua_CentrbByNodes",
}

# Function to generate a short suffix based on the file name
def generate_short_suffix(file_name):
    base_name = os.path.splitext(os.path.basename(file_name))[0]
    parts = base_name.split('_')
    # Use the last two parts of the name as a suffix
    return '_'.join(parts[-2:])

# Read each file and store the data in a dictionary
data_frames = {}

for file, sheet_name in file_sheet_dict.items():
    try:
        # Read the specified sheet
        df = pd.read_excel(file, sheet_name=sheet_name)
        
        # Select only columns containing 'Indeg', 'OutDeg', 'Degree', or 'id'
        cols_to_keep = [col for col in df.columns if re.fullmatch(r'Indeg|OutDeg|Degree|id', col)]
        df = df[cols_to_keep]
        
        # Generate a short suffix based on the file name
        suffix = generate_short_suffix(file)
        
        # Add suffix to the columns
        df = df.add_suffix(f'_{suffix}')
        
        # Rename the id column to have a consistent name
        df = df.rename(columns={f'id_{suffix}': 'id'})
        
        data_frames[suffix] = df
        print(f"File {file} read successfully with suffix {suffix}.")
    except Exception as e:
        print(f"Error reading file {file}: {e}")

# Initialize the resulting DataFrame with the first DataFrame in the dictionary
result_df = None

for suffix, df in data_frames.items():
    if result_df is None:
        result_df = df
    else:
        result_df = pd.merge(result_df, df, on='id', how='outer')

# Save the resulting DataFrame to an Excel file
output_path = "../DataIntermediate/combined_data_dep_variables_indeg_outdeg.csv"
os.makedirs("../DataIntermediate/", exist_ok=True)
try:
    # Remove the row with the producer name 'Sumfone Tagadad'
    result_df = result_df[result_df['id'] != 'Sumfone Tagadad']
    result_df.to_csv(output_path, index=False)
    print(f"Combined file saved successfully at {output_path}.")
    print(f"Dimensions of the resulting DataFrame: {result_df.shape}")
except Exception as e:
    print(f"Error saving the combined file: {e}")
# Out:
# Archivo ../DataIn/VarDep/23_Var.Dep_Rede_EntreajudaLabur.xlsx leído exitosamente con sufijo Rede_EntreajudaLabur.
# Archivo ../DataIn/VarDep/24_Var.Dep_RedeControlExtAusencia.xlsx leído exitosamente con sufijo Var.Dep_RedeControlExtAusencia.
# Archivo ../DataIn/VarDep/25_Var.Dep_ApoioSpecDiqCint.xlsx leído exitosamente con sufijo Var.Dep_ApoioSpecDiqCint.
# Archivo ../DataIn/VarDep/26_Var.Dep_ApoioSpecTubos.xlsx leído exitosamente con sufijo Var.Dep_ApoioSpecTubos.
# Archivo ../DataIn/VarDep/29_Var.Dep_RedApoiLevntDiCin.xlsx leído exitosamente con sufijo Var.Dep_RedApoiLevntDiCin.
# Archivo ../DataIn/VarDep/32_Var.Dep_RedCont_DiqPriqDiqCint.xlsx leído exitosamente con sufijo RedCont_DiqPriqDiqCint.
# Archivo ../DataIn/VarDep/35_Var.Dep_RedeRepar_DiqPriqDiqCint.xlsx leído exitosamente con sufijo RedeRepar_DiqPriqDiqCint.
# Archivo ../DataIn/VarDep/36_Var.Dep_Red-Val_Cont1Rep2DiqCin.xlsx leído exitosamente con sufijo Red-Val_Cont1Rep2DiqCin.
# Archivo ../DataIn/VarDep/37_Var.Dep_Red-Val_Cont1Rep2DiqPrq.xlsx leído exitosamente con sufijo Red-Val_Cont1Rep2DiqPrq.
# Archivo ../DataIn/VarDep/38_Var.Dep_Red-Val_ContRep2_DiqPrqCin.xlsx leído exitosamente con sufijo ContRep2_DiqPrqCin.
# Archivo ../DataIn/VarDep/39_Var.Dep_RedePartilhaAgu.xlsx leído exitosamente con sufijo Var.Dep_RedePartilhaAgu.
# Archivo combinado guardado exitosamente en ../DataIntermediate/combined_data_dep_variables_indeg_outdeg.csv.
# Dimensiones del DataFrame resultante: (129, 22)

# %% [markdown]
# ## Export all data of independent variables (indeg as outdeg)

# %%
import pandas as pd
import os
import re

# Dictionary of Excel files with their respective sheets
file_sheet_dict_indep = {
    "../DataIn/VarExpl/0018_Rev_Var.Expl_RedConfliAguaTot.xlsx": "RedConfltAguTot_CentlitybByNod",
    "../DataIn/VarExpl/0019.1_RevV.Expl_RedConfliAguaReso.xlsx": "RedConfliAguaRes_CentlitybByNod",
    "../DataIn/VarExpl/12_Var.Explic_FamiRedIrmonsPrimos.xlsx": "RedeIrmonsPrimo_CentlitybByNods",
    "../DataIn/VarExpl/13_Var.Explic_FamiRedPaiTiopatCriadr.xlsx": "PaiTiopaterCriador_Transp_Centr",
    "../DataIn/VarExpl/14_Var.Explic_FamiRedTiosMaternos.xlsx": "TiosMaternos_Transp_Centr",
    "../DataIn/VarExpl/15.1_V.Expl_Red_IntimAmigUndir.xlsx": "IntimAmigUndi_CentalitybByNodes",
    "../DataIn/VarExpl/15_Var.Explic_Rede_IntimAmigos.xlsx": "IntimAmigos_CentalitybByNodes",
    "../DataIn/VarExpl/16_Var.Explic_RedeRisk.xlsx": "RedeRisk_CentalitybByNodes",
    "../DataIn/VarExpl/17_Var.Explic_Rede_Confianca.xlsx": "RedeConfianca_CentalityByNodes",
    "../DataIn/VarExpl/19_Var.Explic_RedeConflitAguaPersist.xlsx": "RedeConflitAgua_CentlitybByNod",
    "../DataIn/VarExpl/20_RevVar.Expl_RedConflitGeralTot.xlsx": "RedeConflitGerTo_CentlitybByNod",
    "../DataIn/VarExpl/21_Var.Explic_RedeConflitGeralPersist.xlsx": "RedeConflitGerPe_CentlitybByNod",
    "../DataIn/VarExpl/Duda_22.1_Var.Explic_RedeVendaParcel.xlsx": "VendaParcela_Transp_Centr",
    "../DataIn/VarExpl/Duda_22_Var.Explic_RedeEmprestParcel.xlsx": "EmprestParcela_Centr",
    "../DataIn/VarDep/Data_Superf_NumZonas.xlsx": "Data_area",
    "../DataIntermediate/PCA_Dist_Prod.xlsx" : "Distance_Prods",
    "../DataIntermediate/Distancias_promedio_casas_parcelas.xlsx" : "Dist_moranza_parcel",
    "../DataIn/VarExpl/12-13-14_Var.Explic_FamiTotal.xlsx": "RedeTotFamily_CentlitybByNods"
}

# Read each file and store the data in a dictionary
data_frames_indep = {}

for file, sheet_name in file_sheet_dict_indep.items():
    try:
        # Read the Excel file
        df = pd.read_excel(file, sheet_name=sheet_name)
        
        # Select only the columns that exactly contain 'Indeg', 'OutDeg', 'Degree', 'PC1', 'PC2', 'Avg_Distancia', or 'id'
        cols_to_keep = [col for col in df.columns if re.fullmatch(r'Indeg|OutDeg|Degree|PC1|PC2|Avg_Distancia|id', col)]
        df = df[cols_to_keep]
        
        # Generate a short suffix based on the sheet name
        suffix = sheet_name[:12]  # Use the first 12 characters of the sheet name as the suffix
        
        # Add suffix to the columns
        df = df.add_suffix(f'_{suffix}')
        
        # Rename the id column to have a consistent name
        df = df.rename(columns={f'id_{suffix}': 'id'})
        
        data_frames_indep[suffix] = df
        print(f"File {file} read successfully with suffix {suffix}.")
    except Exception as e:
        print(f"Error reading the file {file}: {e}")

# Process the file "Atributos_Productores.xlsx"
atributos_productores_path = "../DataIn/VarExpl/Atributos_Productores.xlsx"
try:
    atributos_productores_df = pd.read_excel(atributos_productores_path, sheet_name="Sheet1")
    print(f"File {atributos_productores_path} read successfully.")
except Exception as e:
    print(f"Error reading the file {atributos_productores_path}: {e}")

# Initialize the resulting DataFrame with the first DataFrame in the dictionary
result_df = None

for suffix, df in data_frames_indep.items():
    if result_df is None:
        result_df = df
    else:
        result_df = pd.merge(result_df, df, on='id', how='outer')

# Combine the resulting DataFrame with the "Atributos_Productores" DataFrame
final_result_df = pd.merge(result_df, atributos_productores_df, on='id', how='outer')

# Remove the row with the producer name 'Sumfone Tagadad'
final_result_df = final_result_df[final_result_df['id'] != 'Sumfone Tagadad']

# Save the resulting DataFrame to a CSV file
output_path = "../DataIntermediate/combined_data_indep_variables_indeg_outdeg.csv"
os.makedirs("../DataIntermediate/", exist_ok=True)
try:
    final_result_df.to_csv(output_path, index=False)
    print(f"Combined file saved successfully at {output_path}.")
    print(f"Dimensions of the resulting DataFrame: {final_result_df.shape}")
except Exception as e:
    print(f"Error saving the combined file: {e}")
# Out:
# Archivo ../DataIn/VarExpl/0018_Rev_Var.Expl_RedConfliAguaTot.xlsx leído exitosamente con sufijo RedConfltAgu.
# Archivo ../DataIn/VarExpl/0019.1_RevV.Expl_RedConfliAguaReso.xlsx leído exitosamente con sufijo RedConfliAgu.
# Archivo ../DataIn/VarExpl/12_Var.Explic_FamiRedIrmonsPrimos.xlsx leído exitosamente con sufijo RedeIrmonsPr.
# Archivo ../DataIn/VarExpl/13_Var.Explic_FamiRedPaiTiopatCriadr.xlsx leído exitosamente con sufijo PaiTiopaterC.
# Archivo ../DataIn/VarExpl/14_Var.Explic_FamiRedTiosMaternos.xlsx leído exitosamente con sufijo TiosMaternos.
# Archivo ../DataIn/VarExpl/15.1_V.Expl_Red_IntimAmigUndir.xlsx leído exitosamente con sufijo IntimAmigUnd.
# Archivo ../DataIn/VarExpl/15_Var.Explic_Rede_IntimAmigos.xlsx leído exitosamente con sufijo IntimAmigos_.
# Archivo ../DataIn/VarExpl/16_Var.Explic_RedeRisk.xlsx leído exitosamente con sufijo RedeRisk_Cen.
# Archivo ../DataIn/VarExpl/17_Var.Explic_Rede_Confianca.xlsx leído exitosamente con sufijo RedeConfianc.
# Archivo ../DataIn/VarExpl/19_Var.Explic_RedeConflitAguaPersist.xlsx leído exitosamente con sufijo RedeConflitA.
# Archivo ../DataIn/VarExpl/20_RevVar.Expl_RedConflitGeralTot.xlsx leído exitosamente con sufijo RedeConflitG.
# Archivo ../DataIn/VarExpl/21_Var.Explic_RedeConflitGeralPersist.xlsx leído exitosamente con sufijo RedeConflitG.
# Archivo ../DataIn/VarExpl/Duda_22.1_Var.Explic_RedeVendaParcel.xlsx leído exitosamente con sufijo VendaParcela.
# Archivo ../DataIn/VarExpl/Duda_22_Var.Explic_RedeEmprestParcel.xlsx leído exitosamente con sufijo EmprestParce.
# Archivo ../DataIn/VarDep/Data_Superf_NumZonas.xlsx leído exitosamente con sufijo Data_area.
# Archivo ../DataIntermediate/PCA_Dist_Prod.xlsx leído exitosamente con sufijo Distance_Pro.
# Archivo ../DataIntermediate/Distancias_promedio_casas_parcelas.xlsx leído exitosamente con sufijo Dist_moranza.
# Archivo ../DataIn/VarExpl/12-13-14_Var.Explic_FamiTotal.xlsx leído exitosamente con sufijo RedeTotFamil.
# Archivo ../DataIn/VarExpl/Atributos_Productores.xlsx leído exitosamente.
# Archivo combinado guardado exitosamente en ../DataIntermediate/combined_data_indep_variables_indeg_outdeg.csv.
# Dimensiones del DataFrame resultante: (129, 37)
